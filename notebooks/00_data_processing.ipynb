# %%
from google.colab import drive
import os
import sys
import importlib

# %%
if not os.path.exists('/content/drive'):
    print("Montando Google Drive...")
    drive.mount('/content/drive')
    print("Google Drive montado.")
else:
    print("Google Drive já está montado.")

EXPERIMENT_PATH = '/content/drive/MyDrive/experimentos_mp'
UTIL_PATH = f'{EXPERIMENT_PATH}/utils'
if UTIL_PATH not in sys.path:
    sys.path.append(UTIL_PATH)
    print(f"'{UTIL_PATH}' adicionado ao sys.path.")
else:
    import data
    importlib.reload(data)
    print(f"'{UTIL_PATH}' já está no sys.path.")

print("\nAmbiente configurado e pronto para importar o módulo de utilidades.")

# %%
from data import Data as data
import pandas as pd

# %% [markdown]
# ## Cível - T2

# %% [markdown]
# ### U1

# %%
dataName = data.civel1()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
dataName = data.civel2()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
dataName = data.civel3()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ## Criminal - T3

# %% [markdown]
# ### U1

# %%
dataName = data.criminal1()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
dataName = data.criminal2()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
dataName = data.criminal3()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ## Eleitoral - T4

# %% [markdown]
# ### U1

# %%
dataName = data.eleitoral1()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
dataName = data.eleitoral2()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
dataName = data.eleitoral3()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ## Fazenda - T5

# %% [markdown]
# ### U1

# %%
dataName = data.fazenda1()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
dataName = data.fazenda2()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
dataName = data.fazenda3()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ## Trabalho - T7

# %% [markdown]
# ### U1

# %%
dataName = data.trabalho1()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U2

# %%
dataName = data.trabalho2()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")

# %% [markdown]
# ### U3

# %%
dataName = data.trabalho3()
df = pd.read_csv(f"{UTIL_PATH}/data/{dataName}.csv.gz")

# %%
df['dataInicio'] = pd.to_datetime(df['dataInicio'])
df = df.sort_values(by=['processoID', 'dataInicio'])

# %%
def filtrar_fluxo(group):

    primeira_atividade = str(group.iloc[0]['activity'])
    ultima_atividade = str(group.iloc[-1]['activity'])

    comecou_distribuicao = 'Distribuição' in primeira_atividade
    terminou_definitivo = 'Definitivo' in ultima_atividade

    return comecou_distribuicao and terminou_definitivo

# 4. Aplicar o filtro por grupo de processoID
# Isso manterá todas as linhas dos processos que atendem ao critério
df_filtrado = df.groupby('processoID').filter(filtrar_fluxo)

# 5. Salvar o resultado em um novo CSV
df_filtrado.to_csv(f'{UTIL_PATH}/data/{dataName}_cleaned.csv.gz', index=False)

# Exibir resultados básicos
print(f"Processos encontrados: {df_filtrado['processoID'].nunique()}")
print(f"O arquivo '{dataName}_cleaned.csv.gz' foi gerado com sucesso.")
